# %%
import sys
import os
import dlib
import glob
import cv2

# %%
predictor_path = "shape_predictor_68_face_landmarks.dat"
faces_folder_path = "C:/Users/Shyamprasad/Desktop/CV/Test/allinone/add"

# %%
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor(predictor_path)
win = dlib.image_window()
i = 0
#subject = 5
#word = 8
#utterance = 10
#frame = 1
for f in glob.glob(os.path.join(faces_folder_path, "*.jpg")):  
    #name = ("S0{}_W0{}_U{}_F0{}".format(subject,word,utterance,frame))
    #frame = frame + 1
    print("Processing file: {}".format(f))
    img = cv2.imread(f)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
    win.clear_overlay()
    win.set_image(img)
    dets = detector(img, 1)
    #print("Number of faces detected: {}".format(len(dets)))
    for k, d in enumerate(dets):
        #print("Detection {}: Left: {} Top: {} Right: {} Bottom: {}".format(
            #k, d.left(), d.top(), d.right(), d.bottom()))
        shape = predictor(img, d)
        i += 1
        xmouthpoints = [shape.part(x).x for x in range(48,67)]
        ymouthpoints = [shape.part(x).y for x in range(48,67)]
        maxx = max(xmouthpoints)
        minx = min(xmouthpoints)
        maxy = max(ymouthpoints)
        miny = min(ymouthpoints)
        avgx = round((maxx+minx)/2)
        avgy = round((maxy+miny)/2)
        #print("xmouthpoints {},ymouthpoints {}, maxx {}, minx {}, maxy {}, miny {},avgx {},avgy {}".format(
            #xmouthpoints,ymouthpoints,maxx,minx,maxy,miny,avgx,avgy))
        #pad = 10
        filename = os.path.splitext(os.path.basename(f))[0]
        #crop_image = img[miny-pad:maxy+pad,minx-pad:maxx+pad]
        pad1 = 12
        pad2 = 24
        crop_image = img[avgy-pad1:avgy+pad1,avgx-pad2:avgx+pad2]
        #print("Size {}".format(crop_image.shape))
        #cv2.imshow('mouth',crop_image)
        cv2.imwrite(filename+'.jpg',crop_image)
        #cv2.waitKey(0)
        #cv2.destroyAllWindows()
        #win.add_overlay(shape)
    #win.add_overlay(dets)
# Out:
# Processing file: C:/Users/Shyamprasad/Desktop/CV/Test/allinone\S01_W01_U01_F1.jpg
# Processing file: C:/Users/Shyamprasad/Desktop/CV/Test/allinone\S01_W01_U01_F10.jpg
# Processing file: C:/Users/Shyamprasad/Desktop/CV/Test/allinone\S01_W01_U01_F2.jpg
# Processing file: C:/Users/Shyamprasad/Desktop/CV/Test/allinone\S01_W01_U01_F3.jpg
# Processing file: C:/Users/Shyamprasad/Desktop/CV/Test/allinone\S01_W01_U01_F4.jpg
# Processing file: C:/Users/Shyamprasad/Desktop/CV/Test/allinone\S01_W01_U01_F5.jpg
# Processing file: C:/Users/Shyamprasad/Desktop/CV/Test/allinone\S01_W01_U01_F6.jpg
# Processing file: C:/Users/Shyamprasad/Desktop/CV/Test/allinone\S01_W01_U01_F7.jpg
# Processing file: C:/Users/Shyamprasad/Desktop/CV/Test/allinone\S01_W01_U01_F8.jpg
# Processing file: C:/Users/Shyamprasad/Desktop/CV/Test/allinone\S01_W01_U01_F9.jpg
# Processing file: C:/Users/Shyamprasad/Desktop/CV/Test/allinone\S01_W01_U02_F1.jpg
# ...

# %%
#Augmentation
import cv2
sampleimg = cv2.imread('color_006.jpg')
cv2.imshow('image',sampleimg)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(width_shift_range=0.1,height_shift_range=0.1,horizontal_flip=True)

# %%
from tensorflow.keras.preprocessing.image import img_to_array
#import matplotlib.pyplot as plt
#import matplotlib.image as mpimg
#img=mpimg.imread('1.jpg')

fullsample = cv2.imread('1.jpg')
x = img_to_array(fullsample) 
#imgplot = plt.imshow(x)
#plt.show()
# Reshaping the input image 
x = x.reshape((1, ) + x.shape)  

# Generating and saving 5 augmented samples  
# using the above defined parameters.  
i = 0
for batch in datagen.flow(x, batch_size = 1, 
                          save_to_dir ='augresult',  
                          save_prefix ='image', save_format ='jpeg'): 
    i += 1
    if i > 2: 
        break

# %%
frames = "C:/Users/Shyamprasad/Desktop/CV/Test/frames"

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread('1.jpg')
imgplot = plt.imshow(img)
plt.show()
